# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Project Title
#
# **Authors:** Gaja Sanch
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
# Import standard packages
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Here you run your code to explore the data
df1= pd.read_csv('ZippedData/bom.movie_gross.csv.gz')
df2= pd.read_csv('ZippedData/imdb.title.basics.csv.gz')
df3= pd.read_csv('ZippedData/imdb.title.ratings.csv.gz')
df4= pd.read_csv('ZippedData/tn.movie_budgets.csv.gz')

# %%
df1.head(10)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
# 8                                Despicable Me   Uni.     251500000.0
# 9                     How to Train Your Dragon   P/DW     217600000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010
# ...

# %%
df1.tail(10)
# Out:
#                              title      studio  domestic_gross foreign_gross  \
# 3377               Let Yourself Go        Men.         12200.0           NaN
# 3378                 Hannah (2018)         PDF         11700.0           NaN
# 3379                      Souvenir      Strand         11400.0           NaN
# 3380  Furious (Legend of Kolovrat)     CARUSEL         10000.0           NaN
# 3381           Beauty and the Dogs       Osci.          8900.0           NaN
# 3382                     The Quake       Magn.          6200.0           NaN
# 3383   Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                      El Pacto        Sony          2500.0           NaN
# 3385                      The Swan  Synergetic          2400.0           NaN
# 3386             An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3377  2018
# 3378  2018
# 3379  2018
# 3380  2018
# 3381  2018
# 3382  2018
# 3383  2018
# 3384  2018
# ...

# %%
df1.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df2.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df2.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df3.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df4.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
#Merging df2 and df3
merged_df23 = pd.merge(df2, df3, on='tconst')
merged_df23.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
merged_df23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.1+ MB

# %%
#droping original title
merged_df23= merged_df23.drop(columns=['original_title'])

# %%
#renaming merged df2 & df3 column title from primary title to title
merged_df23 = merged_df23.rename(columns={'primary_title': 'title'})

# %%
merged_df23.head()
# Out:
#       tconst                            title  start_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh        2013            175.0
# 1  tt0066787  One Day Before the Rainy Season        2019            114.0
# 2  tt0069049       The Other Side of the Wind        2018            122.0
# 3  tt0069204                  Sabse Bada Sukh        2018              NaN
# 4  tt0100275         The Wandering Soap Opera        2017             80.0
#
#                  genres  averagerating  numvotes
# 0    Action,Crime,Drama            7.0        77
# 1       Biography,Drama            7.2        43
# 2                 Drama            6.9      4517
# 3          Comedy,Drama            6.1        13
# 4  Comedy,Drama,Fantasy            6.5       119

# %%
merged_df23.isna().sum()
# Out:
# tconst                0
# title                 0
# start_year            0
# runtime_minutes    7620
# genres              804
# averagerating         0
# numvotes              0
# dtype: int64

# %%
#splitting merged df2 & df3 multiple values in "Genre" column to single values
merged_df23 = merged_df23.assign(genres=merged_df23['genres'].str.split(',')).explode('genres')
merged_df23.head(10)
# Out:
#       tconst                            title  start_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh        2013            175.0
# 0  tt0063540                        Sunghursh        2013            175.0
# 0  tt0063540                        Sunghursh        2013            175.0
# 1  tt0066787  One Day Before the Rainy Season        2019            114.0
# 1  tt0066787  One Day Before the Rainy Season        2019            114.0
# 2  tt0069049       The Other Side of the Wind        2018            122.0
# 3  tt0069204                  Sabse Bada Sukh        2018              NaN
# 3  tt0069204                  Sabse Bada Sukh        2018              NaN
# 4  tt0100275         The Wandering Soap Opera        2017             80.0
# 4  tt0100275         The Wandering Soap Opera        2017             80.0
#
#       genres  averagerating  numvotes
# 0     Action            7.0        77
# 0      Crime            7.0        77
# ...

# %%
merged_df23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129294 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           129294 non-null  object
#  1   title            129294 non-null  object
#  2   start_year       129294 non-null  int64
#  3   runtime_minutes  118953 non-null  float64
#  4   genres           128490 non-null  object
#  5   averagerating    129294 non-null  float64
#  6   numvotes         129294 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 7.9+ MB

# %%
merged_df23.isna().sum()
# Out:
# tconst                 0
# title                  0
# start_year             0
# runtime_minutes    10341
# genres               804
# averagerating          0
# numvotes               0
# dtype: int64

# %%
#rename df4 column name "movie" to "title"
df4 = df4.rename(columns={'movie': 'title'})
df4.head(100)
# Out:
#      id  release_date                                        title  \
# 0     1  Dec 18, 2009                                       Avatar
# 1     2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     3   Jun 7, 2019                                 Dark Phoenix
# 3     4   May 1, 2015                      Avengers: Age of Ultron
# 4     5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..  ...           ...                                          ...
# 95   96   Mar 8, 2019                               Captain Marvel
# 96   97  Apr 15, 2016                              The Jungle Book
# 97   98  Jun 19, 2015                                   Inside Out
# 98   99   Jul 7, 2017                       Spider-Man: Homecoming
# 99  100   Aug 5, 2016                                Suicide Squad
#
#    production_budget domestic_gross worldwide_gross
# 0       $425,000,000   $760,507,625  $2,776,345,279
# 1       $410,600,000   $241,063,875  $1,045,663,875
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   title              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
merged_df23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129294 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           129294 non-null  object
#  1   title            129294 non-null  object
#  2   start_year       129294 non-null  int64
#  3   runtime_minutes  118953 non-null  float64
#  4   genres           128490 non-null  object
#  5   averagerating    129294 non-null  float64
#  6   numvotes         129294 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 7.9+ MB

# %%
#merge df2 &df4 based on the column "title"
merged_df2df4 = pd.merge(merged_df23, df4, on='title')

merged_df2df4.head()
# Out:
#       tconst          title  start_year  runtime_minutes     genres  \
# 0  tt0249516     Foodfight!        2012             91.0     Action
# 1  tt0249516     Foodfight!        2012             91.0  Animation
# 2  tt0249516     Foodfight!        2012             91.0     Comedy
# 3  tt0326592  The Overnight        2010             88.0        NaN
# 4  tt3844362  The Overnight        2015             79.0     Comedy
#
#    averagerating  numvotes  id  release_date production_budget domestic_gross  \
# 0            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 1            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 2            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 3            7.5        24  21  Jun 19, 2015          $200,000     $1,109,808
# 4            6.1     14828  21  Jun 19, 2015          $200,000     $1,109,808
#
#   worldwide_gross
# 0         $73,706
# 1         $73,706
# 2         $73,706
# ...

# %%
merged_df2df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6452 entries, 0 to 6451
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             6452 non-null   object
#  1   title              6452 non-null   object
#  2   start_year         6452 non-null   int64
#  3   runtime_minutes    6298 non-null   float64
#  4   genres             6444 non-null   object
#  5   averagerating      6452 non-null   float64
#  6   numvotes           6452 non-null   int64
#  7   id                 6452 non-null   int64
#  8   release_date       6452 non-null   object
#  9   production_budget  6452 non-null   object
#  10  domestic_gross     6452 non-null   object
#  11  worldwide_gross    6452 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 655.3+ KB

# %%
merged_df2df4.isna().sum()
# Out:
# tconst                 0
# title                  0
# start_year             0
# runtime_minutes      154
# genres                 8
# averagerating          0
# numvotes               0
# id                     0
# release_date           0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# dtype: int64

# %%
#dropping NAN values and assigning to new df5
df5=merged_df2df4.dropna()
df5.isna().sum()
# Out:
# tconst               0
# title                0
# start_year           0
# runtime_minutes      0
# genres               0
# averagerating        0
# numvotes             0
# id                   0
# release_date         0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
#determining the number of movies in the merged df5
df5['title'].value_counts()
# Out:
# Home                                       45
# The Gambler                                20
# Brothers                                   20
# The Return                                 18
# The Gift                                   18
#                                            ..
# The Rock                                    1
# Aloft                                       1
# Bathory                                     1
# Living Dark: The Story of Ted the Caver     1
# Krisha                                      1
# Name: title, Length: 2092, dtype: int64

# %%
df5.head()
# Out:
#       tconst          title  start_year  runtime_minutes     genres  \
# 0  tt0249516     Foodfight!        2012             91.0     Action
# 1  tt0249516     Foodfight!        2012             91.0  Animation
# 2  tt0249516     Foodfight!        2012             91.0     Comedy
# 4  tt3844362  The Overnight        2015             79.0     Comedy
# 5  tt3844362  The Overnight        2015             79.0    Mystery
#
#    averagerating  numvotes  id  release_date production_budget domestic_gross  \
# 0            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 1            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 2            1.9      8248  26  Dec 31, 2012       $45,000,000             $0
# 4            6.1     14828  21  Jun 19, 2015          $200,000     $1,109,808
# 5            6.1     14828  21  Jun 19, 2015          $200,000     $1,109,808
#
#   worldwide_gross
# 0         $73,706
# 1         $73,706
# 2         $73,706
# ...

# %%
#removing $ sign from  "gross income " and converting the data type from object to integer 
df5['worldwide_gross'] = df5['worldwide_gross'].replace('[\$,]', '', regex=True).astype(float)
df5['domestic_gross'] = df5['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)
df5['production_budget'] = df5['production_budget'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# C:\Users\sri_s\AppData\Local\Temp\ipykernel_9356\2210870902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['worldwide_gross'] = df5['worldwide_gross'].replace('[\$,]', '', regex=True).astype(float)
# C:\Users\sri_s\AppData\Local\Temp\ipykernel_9356\2210870902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['domestic_gross'] = df5['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6293 entries, 2962 to 3446
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             6293 non-null   object
#  1   title              6293 non-null   object
#  2   start_year         6293 non-null   int64
#  3   runtime_minutes    6293 non-null   float64
#  4   genres             6293 non-null   object
#  5   averagerating      6293 non-null   float64
#  6   numvotes           6293 non-null   int64
#  7   id                 6293 non-null   int64
#  8   release_date       6293 non-null   object
#  9   production_budget  6293 non-null   float64
#  10  domestic_gross     6293 non-null   float64
#  11  worldwide_gross    6293 non-null   float64
#  12  box office         6293 non-null   float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 688.3+ KB

# %%
df5.isna().sum()
# Out:
# tconst               0
# title                0
# start_year           0
# runtime_minutes      0
# genres               0
# averagerating        0
# numvotes             0
# id                   0
# release_date         0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
df5.head()
# Out:
#       tconst          title  start_year  runtime_minutes     genres  \
# 0  tt0249516     Foodfight!        2012             91.0     Action
# 1  tt0249516     Foodfight!        2012             91.0  Animation
# 2  tt0249516     Foodfight!        2012             91.0     Comedy
# 4  tt3844362  The Overnight        2015             79.0     Comedy
# 5  tt3844362  The Overnight        2015             79.0    Mystery
#
#    averagerating  numvotes  id  release_date  production_budget  \
# 0            1.9      8248  26  Dec 31, 2012         45000000.0
# 1            1.9      8248  26  Dec 31, 2012         45000000.0
# 2            1.9      8248  26  Dec 31, 2012         45000000.0
# 4            6.1     14828  21  Jun 19, 2015           200000.0
# 5            6.1     14828  21  Jun 19, 2015           200000.0
#
#    domestic_gross  worldwide_gross
# 0             0.0          73706.0
# 1             0.0          73706.0
# 2             0.0          73706.0
# ...

# %%
#covert box office values  to million
df5['box office']= (df5['worldwide_gross']+ df5['domestic_gross'])
df5['box office']=round(df5['box office']/1e+06,1)
# Out:
# C:\Users\sri_s\AppData\Local\Temp\ipykernel_9356\2108029659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['box office']= (df5['worldwide_gross']+ df5['domestic_gross'])
# C:\Users\sri_s\AppData\Local\Temp\ipykernel_9356\2108029659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['box office']=round(df5['box office']/1e+06,1)

# %%
#convert production buget values  to million
df5['production_budget']=round(df5['production_budget']/1e+06,1)
# Out:
# C:\Users\sri_s\AppData\Local\Temp\ipykernel_9356\2610632193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['production_budget']=round(df5['production_budget']/1e+06,1)

# %%
df5.head(10)
# Out:
#        tconst          title  start_year  runtime_minutes     genres  \
# 0   tt0249516     Foodfight!        2012             91.0     Action
# 1   tt0249516     Foodfight!        2012             91.0  Animation
# 2   tt0249516     Foodfight!        2012             91.0     Comedy
# 4   tt3844362  The Overnight        2015             79.0     Comedy
# 5   tt3844362  The Overnight        2015             79.0    Mystery
# 6   tt0337692    On the Road        2012            124.0  Adventure
# 7   tt0337692    On the Road        2012            124.0      Drama
# 8   tt0337692    On the Road        2012            124.0    Romance
# 9   tt4339118    On the Road        2014             89.0      Drama
# 10  tt5647250    On the Road        2016            121.0      Drama
#
#     averagerating  numvotes  id  release_date  production_budget  \
# 0             1.9      8248  26  Dec 31, 2012               45.0
# 1             1.9      8248  26  Dec 31, 2012               45.0
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6293 entries, 2962 to 3446
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             6293 non-null   object
#  1   title              6293 non-null   object
#  2   start_year         6293 non-null   int64
#  3   runtime_minutes    6293 non-null   float64
#  4   genres             6293 non-null   object
#  5   averagerating      6293 non-null   float64
#  6   numvotes           6293 non-null   int64
#  7   id                 6293 non-null   int64
#  8   release_date       6293 non-null   object
#  9   production_budget  6293 non-null   float64
#  10  domestic_gross     6293 non-null   float64
#  11  worldwide_gross    6293 non-null   float64
#  12  box office         6293 non-null   float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 688.3+ KB

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
#bar graph between box offcie AVERAGE  and genre
df5_grouped=df5.groupby('genres')['box office'].mean()
sorted_data = df5_grouped.sort_values(ascending=False)
sorted_data.head(10).plot(kind='bar', x='genres', y='box office',color='Green', figsize=(10, 6))
plt.title('BOX OFFICE AVERAGE VS GENRE')
plt.xlabel('Genre')
plt.ylabel('Box office(Million USD)')
plt.show()

# %%
#bar graph between box office Median  and genre
df5_median=df5.groupby('genres')['box office'].median()
sorted_data = df5_median.sort_values(ascending=False)
sorted_data.head(10).plot(kind='bar', x='genres', y='box office',color='OLIVE', figsize=(10, 6))
plt.title('BOX OFFICE MIDDLE VS GENRE')
plt.xlabel('Genre')
plt.ylabel('Box office(Million USD)')
plt.show()

# %%
df6_grouped=df5.groupby('genres')['box office'].median()
sorted_data = df6_grouped.sort_values(ascending=False)
top_10_genres = sorted_data.head(6)
filtered_df = df5[df5['genres'].isin(top_10_genres.index)]
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='production_budget', y='box office',  data=filtered_df )
sns.scatterplot(data=filtered_df , x='production_budget', y='box office', hue='genres', ax=ax)
plt.xlim(30, 200)
plt.ylim(30, 1000)
plt.show()

# %%
df5_median=df5.groupby('genres')['production_budget'].mean()
sorted_data = df5_median.sort_values(ascending=False)
sorted_data.head(10).plot(kind='bar', x='genres', y='production_budget',color='orange', figsize=(10, 6))
plt.title('BUDGET VS GENRE')
plt.xlabel('GENRE')
plt.ylabel('BUDGET(Million USD)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='box office', y='averagerating',  data=filtered_df )
sns.scatterplot(data=filtered_df , x='box office', y='averagerating', hue='genres', ax=ax)
plt.xlim(0,1000)
plt.ylim(0, 10)
plt.show()

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# ## Conclusions
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
